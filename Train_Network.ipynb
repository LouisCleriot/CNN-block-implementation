# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp -r drive/MyDrive/RN/tp2-ift780/* .
# Out:
# Mounted at /content/drive

# %%
#
# si vous êtes sur Colab, assurez vous que vous avec bien sélectionné un GPU (Runtime->Change runtime type)
#
import torch
device = 'GPU' if torch.cuda.is_available() else 'CPU'
print('Vous utilisez le {} '.format(device))
# Out:
# Vous utilisez le CPU

# %%
# !python train_yournet.py --model=YourNet --dataset=cifar10 --batch_size=80 --num-epochs=40 --lr=0.0007  --out best.png --data_aug

# %%
from IPython.display import Image

Image('best.png')
