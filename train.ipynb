# %%
"""
from google.colab import drive
drive.mount('/content/drive')
# !cp -r drive/MyDrive/cnn-blocks/* .
"""
# Out:
# "\nfrom google.colab import drive\ndrive.mount('/content/drive')\n!cp -r drive/MyDrive/cnn-blocks/* .\n"

# %%
from trainer import Trainer
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Class Trainer():
#
#     def __init__ (
#         self, model="ConvMixer", dataset="MathDataset", optimizer="Adam", batch_size=64,
#         num_epochs=10, validation=0.1, learning_rate=0.01, data_aug=False, loss="ce",
#         metric="accuracy", out="fig.png", **model_args):

# %%
model_args = {
    "in_channels": 3,
    "embed_dim": 16,
    "patch_size": 8,
    "kernel_size": 3,
    "depth": 4,
    "num_classes": 16
}

# %%
parameters = { 
    "model": "ConvMixer", 
    "dataset": "MathDataset", 
    "optimizer": "Adam",
    "batch_size": 64, 
    "num_epochs": 10, 
    "validation": 0.1, 
    "learning_rate": 0.01, 
    "data_aug": False, 
    "loss": "ce", 
    "metric": "f1", 
    "out": "fig.png",
    **model_args
}

# %%
trainer = Trainer(**parameters)
# Out:
# Dataset MathDataset not found in torchvision.datasets
# checking for custom dataset
# Dataset MathDataset found in datasets_class
# Optimizer Adam found in torch.optim
# Model ConvMixer found in models

# %%
trainer.train()
# Out:
# Training str on MathDataset for 10 epochs
# Epoch: 1 of 10
# 100%|██████████| 87/87 [00:03<00:00, 25.44it/s, loss=1.650]
# Validation loss 1.724
# Epoch: 2 of 10
# 100%|██████████| 87/87 [00:03<00:00, 26.39it/s, loss=0.600]
# Validation loss 1.701
# Epoch: 3 of 10
# 100%|██████████| 87/87 [00:03<00:00, 24.97it/s, loss=0.322]
# Validation loss 1.339
# Epoch: 4 of 10
# 100%|██████████| 87/87 [00:03<00:00, 25.04it/s, loss=0.223]
# Validation loss 1.648
# Epoch: 5 of 10
# 100%|██████████| 87/87 [00:03<00:00, 25.30it/s, loss=0.174]
# Validation loss 4.504
# Epoch: 6 of 10
# 100%|██████████| 87/87 [00:03<00:00, 24.16it/s, loss=0.128]
# Validation loss 0.418
# Epoch: 7 of 10
# 100%|██████████| 87/87 [00:03<00:00, 23.64it/s, loss=0.116]
# Validation loss 0.241
# Epoch: 8 of 10
# 100%|██████████| 87/87 [00:03<00:00, 25.37it/s, loss=0.093]
# Validation loss 0.346
# Epoch: 9 of 10
# 100%|██████████| 87/87 [00:03<00:00, 22.92it/s, loss=0.102]
# Validation loss 0.476
# Epoch: 10 of 10
# ...

# %%
trainer.test()
# Out:
# Accuracy on the test set: 99.996 %
